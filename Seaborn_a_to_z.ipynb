# %% [markdown]
# # 1- SeaBorn Plots

# %% [markdown]
# ## 1.1- Barplot

# %%
#import library
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#set theme
sns.set_theme(style='whitegrid')

# %%
ss = pd.read_excel("D:\git\jaan_repo\datasets/superstore.xls", sheet_name='Orders')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
ss.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9983 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
#load dataset
tips = sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')
penguins = sns.load_dataset("penguins")
flights = sns.load_dataset("flights")

# %%
#see head
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
#see shape
tips.shape
# Out:
# (244, 7)

# %%
# Syntax

seaborn.barplot(data=None, 
                x=None, y=None, hue=None, 
                order=None, hue_order=None,
                estimator='mean', errorbar=('ci', 95), 
                n_boot=1000, units=None, seed=None, 
                orient=None, color=None, 
                palette=None, saturation=0.75, width=0.8, 
                errcolor='.26', 
                errwidth=None, capsize=None, dodge=True, 
                ci='deprecated', ax=None, **kwargs)

# %% [markdown]
# | Parameter | Description |
# | --- | --- |
# | data | **DataFrame** DataFrame Jahan sy x,y column lainy hen |
# | x | **Variable** Wo variable jisy x axis par rakhna hai |
# | y |**Variable** Wo variable jisy y axis par rakhna hai |
# | hue |**Variable** Wo variable Jisy Colors ky hisab sy show karwaya jay |
# | order |**List of String** Categorical variables ki tarteeb to change karny ka liya |
# | hue_order | **List of String** hue ka Categorical variables ki tarteeb to change karny ka liya |
# | estimator | Statistical function to estimate within each categorical bin, can be None to use a count. |
# |errorbar| If True, draw a data-dependent error bar to indicate standard error, confidence interval, or other estimate of the central tendency of the plot. |
# | ci | **int (0-100)** 0 for no confidence and 100 for full confidence |
# | n_boot | Number of bootstrap iterations to use when computing confidence intervals. |
# | units | Identifier of sampling units, which will be used to perform a multilevel bootstrap and account for repeated measures design. |
# | orient |**"h" or "v"**  Orientation ko Horizontal ya vertical mein change karny ka liya. |
# | color |**Color Name** Graph ka color change karny ka liya |
# | palette |**palette name** color combinations   |
# | saturation | **int** Color ko halka ya garha karny ky liya. 0.5 for half, 1 for orignal and 2 for double |
# | errcolor | Color for all of the error bars. |
# | errwidth | Width of the error bars. |
# | capsize | **int (0.1 - onwards** Capsize change karny ky liya |
# | dodge | If True, the bars are shifted along the categorical axis. |
# | ax | Axes object to draw the plot onto, otherwise uses the current Axes. |

# %% [markdown]
# ### 1.1.1- **x** and **y** Parameters

# %%
#set plot
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')
## 'y' dependent variable hai or 'x' independent variable
## barplot mein hum x axis py categorical variable or y py numerical variable pass karte hai

# %% [markdown]
# ### 1.1.2- **Hue** Parameter

# %%
# before

ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# after

ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    hue = 'Ship Mode')

    ##'hue' parameter ki waja sy ham kisi bhi colomn ki har category ki bar daikh sakty hen
    ## jesy is exemple mein hum ne 'Ship Mode' ki waja sy har region ki har ship mode ki bar daikh sakty hen

# %% [markdown]
# ### 1.1.3- **Order** Parameter

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# after
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    order = ['East', 'West','South', 'Central'])

## Required column jo 'x' axis py set kia hai uski categories ko apni marzi sy tarteb dainy kay liya.
## Above example mein daikh sakty hen ka 'South', "west",'central' or "east' thi
## jisy ham ny reset kar diya

# %% [markdown]
# ### 1.1.4- **hue_order** Parameter

# %%
# before
aax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    hue = 'Ship Mode')

# %%
# after
ax = sns.barplot(data = ss,
                 x = 'Region', y = 'Sales',
                 hue = 'Ship Mode', 
                 hue_order = ['Same Day', 'First Class', 'Second Class', 'Standard Class'])

## is parameter ko use karty hue ki tarteeb change kar sakty hen

# %% [markdown]
# ### 1.1.5- **Estimator** Parameter

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# after

#import numpy
from numpy import median
##numerical values or mathematical operaors sy deal karny ka liya numpy use ki jati hai

# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    estimator = median)

## Above graph mein astimator 'mean' tha magar hum ny 'median' set kia

# %% [markdown]
# ### 1.1.6- **ci (Confidence Interval)** Parameter

# %% [markdown]
# **Confidence Interval** ko agar one line mein explane karon to ya ho ga ka agar mein ci = 90 set karta hon to iska matlab hai ka mery ghalat hony ka 10% chance hai.

# %%
# without applying ci 
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# with applying ci
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    ci = 70)

## 'ci' ki value 0-100 ho gi
# Out:
# C:\Users\Jahanzaib\AppData\Local\Temp\ipykernel_11276\4261742813.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 70)` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# ### 1.1.7- **Capsize** Parameter

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    capsize = .2)

## You can see ka capsize parameter use karny sy error bar ky  oper caps lag gae hen

# %% [markdown]
# ### 1.1.8- **Errorbar** Parameter

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    errorbar="sd")

## errorbar parameter mein statical  values change kar saktyhen

# %%
ax = sns.barplot(
    data = titanic,
    x = 'sex', y = 'age',
    errorbar="sd")

# %% [markdown]
# ### 1.1.9- **Errcolor** Parameter

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    errcolor=".5")

## error color ki value change karny sy error bar ka color ki saturation change ho jati hai

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    errcolor="red")
## or color name put karny sy  color change ho jati hai

# %% [markdown]
# ### 1.1.10- **Errwidth** Parameter

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    errwidth = 0.5)

## error width change karny liya errwidth parameter use kiya hai

# %% [markdown]
# ### 1.1.11- **Orient** Parameter

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales')

# %%
# before
ax = sns.barplot(
    data = ss,
    x = 'Sales', y ='Region',
    orient="h")

## Graph ki orientation change karny ka liya orient parameter use kiya hai

# %% [markdown]
# ### 1.1.12- **Color** Parameter

# %%
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    color = "Gold")

## bars ka color change karny ka liya color parameter use kiya hai

# %%
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    color = "Gold")
ax.patches[2].set_color("red")

## kisi specific bar ka color change karny ka liya patches ka use kiya hai

# %% [markdown]
# #### 1.1.9.1- Color Names and Codes

# %% [markdown]
# ![Alt text](resources/color_names_codes_1.png)

# %% [markdown]
# ![Alt text](resources/color_names_codes_2.png)

# %% [markdown]
# ![Alt text](resources/color_names_codes_3.png)

# %% [markdown]
# ### 1.1.13- **Saturation** Parameter

# %%
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    color = "hotpink",saturation=0.50)

## colors ki saturation change karny ka liya saturation parameter use kiya hai

# %% [markdown]
# ### 1.1.14- **Width** Parameter

# %%
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    width = 0.3)

## width parameter use karny sy bar ka width change ho jata hai
## Horizontal bar ky liya width ki bajay 'height' use kia jata hai

# %% [markdown]
# ### 1.1.15- **Edgecolor** Parameter

# %%
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    edgecolor = "black")

## bar ky around barder line lagany ka liya edgecolor parameter use kiya hai

# %% [markdown]
# ### 1.1.16- **Linewidth** Parameter

# %%
ax = sns.barplot(
    data = ss,
    x = 'Region', y = 'Sales',
    edgecolor = "black",
    linewidth = 3)

## border ki linewidth change karny ka liya linewidth parameter use kiya hai

# %% [markdown]
# ### 1.1.17- **Dodge** Parameter

# %%
ax = sns.barplot(data = ss,
                 x = 'Region', y = 'Sales',
                 hue = 'Ship Mode')

# %%
sorted_data = ss.sort_values(by="Ship Mode", ascending=False)
sns.barplot(data=sorted_data,
             x = 'Region', y = 'Sales',
                 hue = 'Ship Mode',
            dodge=False)
# Out:
# <AxesSubplot: xlabel='Region', ylabel='Sales'>

# %%
sns.barplot(data=titanic,
            x="sex", y="fare", hue="embarked")
# Out:
# <AxesSubplot: xlabel='sex', ylabel='fare'>

# %%
sorted_data = titanic.sort_values(by="fare", ascending=False)
sns.barplot(data=sorted_data,
            x="sex", y="fare", hue="embarked",
            dodge=False)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='fare'>

# %% [markdown]
# ### 1.1.18- **Palette** Parameter

# %%
#import library
import seaborn as sns

#set theme
sns.set_theme(style='whitegrid')

#load dataset
tips = sns.load_dataset('tips')

ax = sns.barplot(
    data = tips,
    x = 'size', y = 'total_bill',
    palette = 'Blues_d')

# %% [markdown]
# #### 1.1.18.1 Color Palettes

# %% [markdown]
# - Perceptually Uniform Palettes
# 1. "rocket"
# 2. "mako"
# 3. "flare"
# 4. "crest
# 5. "magma"
# 6. "viridis"
#
# Note: use suffix "_r" to make the reverse colormap.
# like, rocket_r, mako_r
#
# to make the continuous map into discrete remove last 'as_cmap = True' or put it as False

# %%
sns.color_palette('rocket', as_cmap = True)

# %%
sns.color_palette('rocket_r', as_cmap = True)
##Alternate
#sns.color_palette('rocket',reverse = True as_cmap = True)

# %%
sns.color_palette('rocket', as_cmap = False)
# Out:
# [(0.20973515, 0.09747934, 0.24238489),
#  (0.43860848, 0.12177004, 0.34119475),
#  (0.67824099, 0.09192342, 0.3504148),
#  (0.8833417, 0.19830556, 0.26014181),
#  (0.95381595, 0.46373781, 0.31769923),
#  (0.96516917, 0.70776351, 0.5606593)]

# %%
sns.color_palette('rocket')
# Out:
# [(0.20973515, 0.09747934, 0.24238489),
#  (0.43860848, 0.12177004, 0.34119475),
#  (0.67824099, 0.09192342, 0.3504148),
#  (0.8833417, 0.19830556, 0.26014181),
#  (0.95381595, 0.46373781, 0.31769923),
#  (0.96516917, 0.70776351, 0.5606593)]

# %%
sns.color_palette('mako', as_cmap = True)

# %%
sns.color_palette('flare', as_cmap = True)

# %%
sns.color_palette('crest', as_cmap = True)

# %%
sns.color_palette('magma', as_cmap = True)

# %%
sns.color_palette('viridis', as_cmap = True)

# %%
sns.color_palette('coolwarm', as_cmap = True)

# %%
sns.color_palette('Spectral', as_cmap = True)

# %%
sns.color_palette('icefire', as_cmap = True)

# %%
sns.color_palette('vlag', as_cmap = True)

# %%
sns.color_palette('Blues', as_cmap = True)

# %%
sns.color_palette('YlOrBr', as_cmap = True)

# %%
sns.light_palette('seagreen', as_cmap = True)

# %% [markdown]
# #### 1.1.18.2- Same Color

# %%
#import library
import seaborn as sns

#set theme
sns.set_theme(style='whitegrid')

#load dataset
tips = sns.load_dataset('tips')

ax = sns.barplot(
    data = tips,
    x = 'size', y = 'total_bill',
    color = 'red', saturation = .75)

## Saturation command sy color ko halkaya taiz kar sakty hen iski value 0-1 ky darmiyan ho gi
## 0 sab sy halka or 1 sab sy taiz

# %% [markdown]
# ## 1.2-Lineplot

# %%
# import libraries
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

## Alternate method
#import matplotlib.pyplot as plt

# %%
#set theme
sns.set_theme(style='whitegrid')

# %%
#load dataset
tips = sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')
penguins = sns.load_dataset("penguins")

fmri = sns.load_dataset('fmri')
fmri.head(3)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033

# %%
fmri.shape
# Out:
# (1064, 5)

# %%
# Syntax

seaborn.lineplot(data=None,
                 x=None, y=None, hue=None,
                 size=None, 
                 style=None, units=None, palette=None,
                 hue_order=None, hue_norm=None, 
                 sizes=None, size_order=None, 
                 size_norm=None, dashes=True, 
                 markers=None, style_order=None, 
                 estimator='mean', errorbar=('ci', 95),
                 n_boot=1000, seed=None, orient='x', 
                 sort=True, err_style='band', 
                 err_kws=None, legend='auto', 
                 ci='deprecated', ax=None, **kwargs)

# %% [markdown]
# | Parameter | Description |
# | --- | --- |
# | data | **DataFrame** DataFrame Jahan sy x,y column lainy hen |
# | x | **Variable** Wo variable jisy x axis par rakhna hai |
# | y |**Variable** Wo variable jisy y axis par rakhna hai |
# | hue |**Variable** Wo variable Jisy Colors ky hisab sy show karwaya jay |
# | order |**List of String** Categorical variables ki tarteeb to change karny ka liya |
# | hue_order | **List of String** hue ka Categorical variables ki tarteeb to change karny ka liya |
# | estimator | Statistical function to estimate within each categorical bin, can be None to use a count. |
# |errorbar| If True, draw a data-dependent error bar to indicate standard error, confidence interval, or other estimate of the central tendency of the plot. |
# | ci | **int (0-100)** 0 for no confidence and 100 for full confidence |
# | n_boot | Number of bootstrap iterations to use when computing confidence intervals. |
# | units | Identifier of sampling units, which will be used to perform a multilevel bootstrap and account for repeated measures design. |
# | orient |**"h" or "v"**  Orientation ko Horizontal ya vertical mein change karny ka liya. |
# | color |**Color Name** Graph ka color change karny ka liya |
# | palette |**palette name** color combinations   |
# | saturation | **int** Color ko halka ya garha karny ky liya. 0.5 for half, 1 for orignal and 2 for double |
# | errcolor | Color for all of the error bars. |
# | errwidth | Width of the error bars. |
# | capsize | **int (0.1 - onwards** Capsize change karny ky liya |
# | dodge | If True, the bars are shifted along the categorical axis. |
# | ax | Axes object to draw the plot onto, otherwise uses the current Axes. |

# %% [markdown]
# ### 1.2.1- **x** and **y** Parameters

# %%
sns.lineplot(data = titanic,
             x = 'age', y = 'fare')
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
plt.figure(figsize=(10,4))
ax = sns.lineplot(
    data= ss,
    x = 'Discount',y ='Profit')
plt.show()

# %%
flights_wide = flights.pivot("year", "month", "passengers")
flights_wide.head()
# Out:
# C:\Users\Jahanzaib\AppData\Local\Temp\ipykernel_11276\1230890992.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_wide = flights.pivot("year", "month", "passengers")
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
sns.lineplot(data=flights_wide["May"])
# Out:
# <AxesSubplot: xlabel='year', ylabel='May'>

# %% [markdown]
# ### 1.2.2- **Hue** Parameter

# %%
# Hue Command
ax = sns.lineplot(
    data= ss,
    x = 'Discount',y ='Profit',
    hue='Segment')
plt.show
## Hue hamesha caegorical variable ho ga
## Hue mein har category ko x,y axis kay mutabiq shoiw karway ga
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lineplot(data=flights, 
             x="year", y="passengers", hue="month")
# Out:
# <AxesSubplot: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### 1.2.3- **Style** Parameter

# %%
sns.lineplot(
    data=flights,
    x="year", y="passengers", hue="month",
    style="month")
# Out:
# <AxesSubplot: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### 1.1.10- **Orient** Parameter

# %%
sns.lineplot(data=flights,
             x="passengers", y="year",
             orient="y")
# Out:
# <AxesSubplot: xlabel='passengers', ylabel='year'>

# %%
sns.lineplot(data=flights,
             x="passengers", y="year",
             orient="y",
             markers=True, dashes=False)
# Out:
# <AxesSubplot: xlabel='passengers', ylabel='year'>

# %%
plt.figure(figsize=(10,4))
ax = sns.lineplot(
    data= ss,
    x = 'Discount',y ='Profit',
    markers=True, dashes=False)
plt.show()

# %% [markdown]
# ## 1.3- Jointplot

# %%
iris = sns.load_dataset('iris')
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
sns.jointplot(x = 'sepal_length', y = 'petal_length', data = iris)
plt.show()

# %%
# Change Color
sns.jointplot(x = 'sepal_length', y = 'petal_length', data = iris, color= 'green')
plt.show()

# %%
# Kind Paramerter
sns.jointplot(x = 'sepal_length', y = 'petal_length', data = iris, color= 'green', kind ='reg')
plt.show()

# %% [markdown]
# ## 1.4- Boxplot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = sns.boxplot(
    data = iris,
    x = "species", y = 'sepal_length')

# %% [markdown]
# ## 1.5- Pairplot

# %%
df = sns.load_dataset("iris")

# %%
ax = sns.pairplot(
    data = df,
    hue = 'species'
)

# %% [markdown]
# ## 1.6- Scatterplot

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# Syntax
seaborn.scatterplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, palette=None, 
                    hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, 
                    markers=True, style_order=None, legend='auto', ax=None, **kwargs)

# %%
# data,x,y

sns.scatterplot(
    data = df,
    x ='total_bill', y = 'tip' )

# data = wo data set jis py plot karna hai
# x = x axis py jo column rakhna hai
# y = y axis py jo column rakhna ha

## Yaad rahy dataset ka naam inverted commas kay baghiar rakhna hai( kunka wo defind hai)
## x,y axis py jo column rakhna hai uska naam inverted commas mein rakhna hai(kunka wo defind nhi hen)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# hue
sns.scatterplot(
    data = df,
    x ='total_bill', y = 'tip',
    hue = 'sex' )

# Agar "hue" mein categorical variable put karen gy to har category kay liya different color show ho ga
# Agar nemeric values put kar rahy hen or unki tadad ziada hai to unky groups ban jaen gy
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# palette
sns.scatterplot(
    data = df,
    x ='total_bill', y = 'tip',
    hue = 'size',
    palette="deep")

# palette parameter sy colors ko change kar sakty hen "palette" mein color ka naam likhna hai
# colors ky name seaborn color palette py check kar sakty hen.
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# hue, size, style

sns.scatterplot(
    data = df,
    x ='total_bill', y = 'tip',
    hue = 'sex', size = 'size', style = 'time' )

# scatterplot minimum do contineous variables py plot hota hai
# third variable(categorical) "hue" py set kar sakty hen is sy points ka color change ho jay ga.
# fourth variable(categorical) "size" py set kar sakty hen is sy points ka size change ho jay ga.
# fifth variable(categorical) "style" py set kar sakty hen is sy points ka style change ho jay ga.
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# sizes

sns.scatterplot(
    data = df,
    x ='total_bill', y = 'tip',
    hue = 'sex', size = 'size',
    sizes = (20, 200))

# sizes param ko use karty hoy minimum or maximum size ko set kar sakty hen
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# hue_norm

sns.scatterplot(
    data=df,
    x="total_bill", y="tip",
    hue="size",
    size="size",
    sizes=(20, 200), 
    hue_norm=(0, 7)
)

# hue_norm param ko use karty hoy hue variable ky values ko normalize kar sakty hen
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(
    data=df,
    x="total_bill", y="tip",
    hue="size",
    size="size",
    sizes=(20, 200), 
    hue_norm=(0, 15)
)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# marker

sns.scatterplot(
    data = df,
    x ='total_bill', y = 'tip',
    hue = 'sex', size = 'size', style = 'time',
    marker = '+')

# marker param use kar ky marzi ka marker set kar sakty hen
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 1.7- Relplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')

# %%
# Syntax

seaborn.relplot(data=None, *, x=None, y=None, hue=None, size=None, style=None,
                units=None, row=None, col=None, col_wrap=None, row_order=None,
                col_order=None, palette=None, hue_order=None, hue_norm=None, 
                sizes=None, size_order=None, size_norm=None, markers=None, 
                dashes=None, style_order=None, legend='auto', kind='scatter', 
                height=5, aspect=1, facet_kws=None, **kwargs)

# %%
sns.relplot(data = df, 
            x="total_bill", y="tip", 
            hue="day")

# %% [markdown]
# ## 1.7- Countplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')

# %%
# Syntax

seaborn.countplot(data=None, *, x=None, y=None, hue=None, order=None, 
                  hue_order=None, orient=None, color=None, palette=None, 
                  saturation=0.75, width=0.8, dodge=True, ax=None, **kwargs)
